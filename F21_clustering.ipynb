# %%
import mlcroissant as mlc
import pandas as pd

dataset = mlc.Dataset('https://www.kaggle.com/datasets/bryanb/fifa-player-stats-database/croissant/download')

fifa_dataset = dataset.metadata.record_sets

fifa_df = pd.DataFrame(dataset.records(record_set=fifa_dataset[4].uuid))
pd.set_option('display.max_columns', None)
fifa_df.head()
# Out:
# WARNING:absl:WARNING: The JSON-LD `@context` is not standard. Refer to the official @context (e.g., from the example datasets in https://github.com/mlcommons/croissant/tree/main/datasets/1.0). The different keys are: {'examples', 'rai', 'samplingRate'}
# WARNING:absl:Found the following 1 warning(s) during the validation:
#   -  [Metadata(FIFA23 OFFICIAL DATASET)] Property "http://mlcommons.org/croissant/citeAs" is recommended, but does not exist.
#   FIFA21_official_data.csv/ID FIFA21_official_data.csv/Name  \
# 0                   b'176580'          b' L. Su\xc3\xa1rez'
# 1                   b'192985'              b' K. De Bruyne'
# 2                   b'212198'           b' Bruno Fernandes'
# 3                   b'194765'              b' A. Griezmann'
# 4                   b'224334'           b' M. Acu\xc3\xb1a'
#
#    FIFA21_official_data.csv/Age  \
# 0                            33
# 1                            29
# 2                            25
# 3                            29
# 4                            28
#
#                       FIFA21_official_data.csv/Photo  \
# 0  b'https://cdn.sofifa.com/players/176/580/20_60...
# 1  b'https://cdn.sofifa.com/players/192/985/20_60...
# 2  b'https://cdn.sofifa.com/players/212/198/20_60...
# 3  b'https://cdn.sofifa.com/players/194/765/20_60...
# 4  b'https://cdn.sofifa.com/players/224/334/20_60...
#
#   FIFA21_official_data.csv/Nationality  \
# 0                           b'Uruguay'
# 1                           b'Belgium'
# 2                          b'Portugal'
# 3                            b'France'
# 4                         b'Argentina'
#
#             FIFA21_official_data.csv/Flag  FIFA21_official_data.csv/Overall  \
# 0  b'https://cdn.sofifa.com/flags/uy.png'                                87
# 1  b'https://cdn.sofifa.com/flags/be.png'                                91
# 2  b'https://cdn.sofifa.com/flags/pt.png'                                87
# 3  b'https://cdn.sofifa.com/flags/fr.png'                                87
# 4  b'https://cdn.sofifa.com/flags/ar.png'                                83
#
#    FIFA21_official_data.csv/Potential FIFA21_official_data.csv/Club  \
# 0                                  87     b'Atl\xc3\xa9tico Madrid'
# 1                                  91            b'Manchester City'
# 2                                  90          b'Manchester United'
# 3                                  87               b'FC Barcelona'
# 4                                  83                 b'Sevilla FC'
#
#                  FIFA21_official_data.csv/Club+Logo  \
# 0  b'https://cdn.sofifa.com/teams/240/light_30.png'
# 1   b'https://cdn.sofifa.com/teams/10/light_30.png'
# 2   b'https://cdn.sofifa.com/teams/11/light_30.png'
# 3  b'https://cdn.sofifa.com/teams/241/light_30.png'
# 4  b'https://cdn.sofifa.com/teams/481/light_30.png'
#
#   FIFA21_official_data.csv/Value FIFA21_official_data.csv/Wage  \
# 0           b'\xe2\x82\xac31.5M'           b'\xe2\x82\xac115K'
# 1             b'\xe2\x82\xac87M'           b'\xe2\x82\xac370K'
# 2             b'\xe2\x82\xac63M'           b'\xe2\x82\xac195K'
# 3           b'\xe2\x82\xac50.5M'           b'\xe2\x82\xac290K'
# 4             b'\xe2\x82\xac22M'            b'\xe2\x82\xac41K'
#
#    FIFA21_official_data.csv/Special FIFA21_official_data.csv/Preferred+Foot  \
# 0                              2316                                b'Right'
# 1                              2304                                b'Right'
# 2                              2303                                b'Right'
# 3                              2288                                 b'Left'
# 4                              2280                                 b'Left'
#
#    FIFA21_official_data.csv/International+Reputation  \
# 0                                                5.0
# 1                                                4.0
# 2                                                2.0
# 3                                                4.0
# 4                                                2.0
#
#    FIFA21_official_data.csv/Weak+Foot  FIFA21_official_data.csv/Skill+Moves  \
# 0                                 4.0                                   3.0
# 1                                 5.0                                   4.0
# 2                                 4.0                                   4.0
# 3                                 3.0                                   4.0
# 4                                 3.0                                   4.0
#
#   FIFA21_official_data.csv/Work+Rate FIFA21_official_data.csv/Body+Type  \
# 0                    b'High/ Medium'            b'PLAYER_BODY_TYPE_374'
# 1                      b'High/ High'            b'PLAYER_BODY_TYPE_321'
# 2                      b'High/ High'                  b'Lean (170-185)'
# 3                  b'Medium/ Medium'            b'PLAYER_BODY_TYPE_266'
# 4                      b'High/ High'                b'Stocky (170-185)'
#
#   FIFA21_official_data.csv/Real+Face FIFA21_official_data.csv/Position  \
# 0                               True     b'<span class="pos pos24">RS'
# 1                               True    b'<span class="pos pos13">RCM'
# 2                               True    b'<span class="pos pos18">CAM'
# 3                               True     b'<span class="pos pos23">RW'
# 4                               True      b'<span class="pos pos7">LB'
#
#    FIFA21_official_data.csv/Jersey+Number FIFA21_official_data.csv/Joined  \
# 0                                     9.0                 b'Sep 25, 2020'
# 1                                    17.0                 b'Aug 30, 2015'
# 2                                    18.0                 b'Jan 30, 2020'
# 3                                     7.0                 b'Jul 12, 2019'
# 4                                    19.0                 b'Sep 14, 2020'
#
#   FIFA21_official_data.csv/Loaned+From  \
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
#
#   FIFA21_official_data.csv/Contract+Valid+Until  \
# 0                                       b'2022'
# 1                                       b'2023'
# 2                                       b'2025'
# 3                                       b'2024'
# 4                                       b'2024'
#
#   FIFA21_official_data.csv/Height FIFA21_official_data.csv/Weight  \
# 0                          b"6'0"                       b'190lbs'
# 1                         b"5'11"                       b'154lbs'
# 2                         b"5'10"                       b'152lbs'
# 3                          b"5'9"                       b'161lbs'
# 4                          b"5'8"                       b'152lbs'
#
#    FIFA21_official_data.csv/Crossing  FIFA21_official_data.csv/Finishing  \
# 0                               80.0                                92.0
# 1                               94.0                                82.0
# 2                               87.0                                77.0
# 3                               83.0                                88.0
# 4                               87.0                                66.0
#
#    FIFA21_official_data.csv/HeadingAccuracy  \
# 0                                      84.0
# 1                                      55.0
# 2                                      58.0
# 3                                      83.0
# 4                                      57.0
#
#    FIFA21_official_data.csv/ShortPassing  FIFA21_official_data.csv/Volleys  \
# 0                                   83.0                              90.0
# 1                                   94.0                              82.0
# 2                                   88.0                              86.0
# 3                                   84.0                              87.0
# 4                                   81.0                              68.0
#
#    FIFA21_official_data.csv/Dribbling  FIFA21_official_data.csv/Curve  \
# 0                                84.0                            86.0
# 1                                88.0                            85.0
# 2                                85.0                            86.0
# 3                                87.0                            86.0
# 4                                87.0                            88.0
#
#    FIFA21_official_data.csv/FKAccuracy  FIFA21_official_data.csv/LongPassing  \
# 0                                 82.0                                  77.0
# 1                                 83.0                                  93.0
# 2                                 87.0                                  87.0
# 3                                 85.0                                  82.0
# 4                                 75.0                                  78.0
#
#    FIFA21_official_data.csv/BallControl  \
# 0                                  84.0
# 1                                  92.0
# 2                                  88.0
# 3                                  89.0
# 4                                  87.0
#
#    FIFA21_official_data.csv/Acceleration  \
# 0                                   72.0
# 1                                   77.0
# 2                                   78.0
# 3                                   80.0
# 4                                   77.0
#
#    FIFA21_official_data.csv/SprintSpeed  FIFA21_official_data.csv/Agility  \
# 0                                  68.0                              76.0
# 1                                  76.0                              78.0
# 2                                  76.0                              79.0
# 3                                  79.0                              91.0
# 4                                  75.0                              82.0
#
#    FIFA21_official_data.csv/Reactions  FIFA21_official_data.csv/Balance  \
# 0                                92.0                              78.0
# 1                                91.0                              76.0
# 2                                86.0                              79.0
# 3                                92.0                              83.0
# 4                                83.0                              90.0
#
#    FIFA21_official_data.csv/ShotPower  FIFA21_official_data.csv/Jumping  \
# 0                                89.0                              69.0
# 1                                91.0                              63.0
# 2                                89.0                              72.0
# 3                                81.0                              90.0
# 4                                82.0                              63.0
#
#    FIFA21_official_data.csv/Stamina  FIFA21_official_data.csv/Strength  \
# 0                              78.0                               85.0
# 1                              89.0                               74.0
# 2                              94.0                               67.0
# 3                              86.0                               63.0
# 4                              90.0                               80.0
#
#    FIFA21_official_data.csv/LongShots  FIFA21_official_data.csv/Aggression  \
# 0                                88.0                                 87.0
# 1                                91.0                                 76.0
# 2                                89.0                                 70.0
# 3                                82.0                                 73.0
# 4                                81.0                                 84.0
#
#    FIFA21_official_data.csv/Interceptions  \
# 0                                    41.0
# 1                                    66.0
# 2                                    74.0
# 3                                    49.0
# 4                                    78.0
#
#    FIFA21_official_data.csv/Positioning  FIFA21_official_data.csv/Vision  \
# 0                                  91.0                             84.0
# 1                                  88.0                             94.0
# 2                                  83.0                             90.0
# 3                                  89.0                             85.0
# 4                                  81.0                             82.0
#
#    FIFA21_official_data.csv/Penalties  FIFA21_official_data.csv/Composure  \
# 0                                83.0                                85.0
# 1                                84.0                                91.0
# 2                                91.0                                86.0
# 3                                86.0                                89.0
# 4                                76.0                                87.0
#
#    FIFA21_official_data.csv/Marking  FIFA21_official_data.csv/StandingTackle  \
# 0                               NaN                                     45.0
# 1                               NaN                                     65.0
# 2                               NaN                                     67.0
# 3                               NaN                                     54.0
# 4                               NaN                                     82.0
#
#    FIFA21_official_data.csv/SlidingTackle  FIFA21_official_data.csv/GKDiving  \
# 0                                    38.0                               27.0
# 1                                    53.0                               15.0
# 2                                    55.0                               12.0
# 3                                    49.0                               14.0
# 4                                    79.0                                8.0
#
#    FIFA21_official_data.csv/GKHandling  FIFA21_official_data.csv/GKKicking  \
# 0                                 25.0                                31.0
# 1                                 13.0                                 5.0
# 2                                 14.0                                15.0
# 3                                  8.0                                14.0
# 4                                 14.0                                13.0
#
#    FIFA21_official_data.csv/GKPositioning  \
# 0                                    33.0
# 1                                    10.0
# 2                                     8.0
# 3                                    13.0
# 4                                    13.0
#
#    FIFA21_official_data.csv/GKReflexes FIFA21_official_data.csv/Best+Position  \
# 0                                 37.0                                  b'ST'
# 1                                 13.0                                 b'CAM'
# 2                                 14.0                                 b'CAM'
# 3                                 14.0                                  b'ST'
# 4                                 14.0                                  b'LB'
#
#    FIFA21_official_data.csv/Best+Overall+Rating  \
# 0                                          87.0
# 1                                          91.0
# 2                                          88.0
# 3                                          87.0
# 4                                          83.0
#
#   FIFA21_official_data.csv/Release+Clause  \
# 0                    b'\xe2\x82\xac64.6M'
# 1                     b'\xe2\x82\xac161M'
# 2                   b'\xe2\x82\xac124.4M'
# 3                   b'\xe2\x82\xac103.5M'
# 4                    b'\xe2\x82\xac46.2M'
#
#    FIFA21_official_data.csv/DefensiveAwareness
# 0                                         57.0
# 1                                         68.0
# 2                                         72.0
# 3                                         59.0
# 4                                         79.0

# %%
fifa_df.columns = [col.split("/")[-1] for col in fifa_df.columns]

# %%
fifa_df.head()
# Out:
#           ID                  Name  Age  \
# 0  b'176580'  b' L. Su\xc3\xa1rez'   33
# 1  b'192985'      b' K. De Bruyne'   29
# 2  b'212198'   b' Bruno Fernandes'   25
# 3  b'194765'      b' A. Griezmann'   29
# 4  b'224334'   b' M. Acu\xc3\xb1a'   28
#
#                                                Photo   Nationality  \
# 0  b'https://cdn.sofifa.com/players/176/580/20_60...    b'Uruguay'
# 1  b'https://cdn.sofifa.com/players/192/985/20_60...    b'Belgium'
# 2  b'https://cdn.sofifa.com/players/212/198/20_60...   b'Portugal'
# 3  b'https://cdn.sofifa.com/players/194/765/20_60...     b'France'
# 4  b'https://cdn.sofifa.com/players/224/334/20_60...  b'Argentina'
#
#                                      Flag  Overall  Potential  \
# 0  b'https://cdn.sofifa.com/flags/uy.png'       87         87
# 1  b'https://cdn.sofifa.com/flags/be.png'       91         91
# 2  b'https://cdn.sofifa.com/flags/pt.png'       87         90
# 3  b'https://cdn.sofifa.com/flags/fr.png'       87         87
# 4  b'https://cdn.sofifa.com/flags/ar.png'       83         83
#
#                         Club  \
# 0  b'Atl\xc3\xa9tico Madrid'
# 1         b'Manchester City'
# 2       b'Manchester United'
# 3            b'FC Barcelona'
# 4              b'Sevilla FC'
#
#                                           Club+Logo                 Value  \
# 0  b'https://cdn.sofifa.com/teams/240/light_30.png'  b'\xe2\x82\xac31.5M'
# 1   b'https://cdn.sofifa.com/teams/10/light_30.png'    b'\xe2\x82\xac87M'
# 2   b'https://cdn.sofifa.com/teams/11/light_30.png'    b'\xe2\x82\xac63M'
# 3  b'https://cdn.sofifa.com/teams/241/light_30.png'  b'\xe2\x82\xac50.5M'
# 4  b'https://cdn.sofifa.com/teams/481/light_30.png'    b'\xe2\x82\xac22M'
#
#                   Wage  Special Preferred+Foot  International+Reputation  \
# 0  b'\xe2\x82\xac115K'     2316       b'Right'                       5.0
# 1  b'\xe2\x82\xac370K'     2304       b'Right'                       4.0
# 2  b'\xe2\x82\xac195K'     2303       b'Right'                       2.0
# 3  b'\xe2\x82\xac290K'     2288        b'Left'                       4.0
# 4   b'\xe2\x82\xac41K'     2280        b'Left'                       2.0
#
#    Weak+Foot  Skill+Moves          Work+Rate                Body+Type  \
# 0        4.0          3.0    b'High/ Medium'  b'PLAYER_BODY_TYPE_374'
# 1        5.0          4.0      b'High/ High'  b'PLAYER_BODY_TYPE_321'
# 2        4.0          4.0      b'High/ High'        b'Lean (170-185)'
# 3        3.0          4.0  b'Medium/ Medium'  b'PLAYER_BODY_TYPE_266'
# 4        3.0          4.0      b'High/ High'      b'Stocky (170-185)'
#
#   Real+Face                        Position  Jersey+Number           Joined  \
# 0      True   b'<span class="pos pos24">RS'            9.0  b'Sep 25, 2020'
# 1      True  b'<span class="pos pos13">RCM'           17.0  b'Aug 30, 2015'
# 2      True  b'<span class="pos pos18">CAM'           18.0  b'Jan 30, 2020'
# 3      True   b'<span class="pos pos23">RW'            7.0  b'Jul 12, 2019'
# 4      True    b'<span class="pos pos7">LB'           19.0  b'Sep 14, 2020'
#
#   Loaned+From Contract+Valid+Until   Height     Weight  Crossing  Finishing  \
# 0        None              b'2022'   b"6'0"  b'190lbs'      80.0       92.0
# 1        None              b'2023'  b"5'11"  b'154lbs'      94.0       82.0
# 2        None              b'2025'  b"5'10"  b'152lbs'      87.0       77.0
# 3        None              b'2024'   b"5'9"  b'161lbs'      83.0       88.0
# 4        None              b'2024'   b"5'8"  b'152lbs'      87.0       66.0
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  \
# 0             84.0          83.0     90.0       84.0   86.0        82.0
# 1             55.0          94.0     82.0       88.0   85.0        83.0
# 2             58.0          88.0     86.0       85.0   86.0        87.0
# 3             83.0          84.0     87.0       87.0   86.0        85.0
# 4             57.0          81.0     68.0       87.0   88.0        75.0
#
#    LongPassing  BallControl  Acceleration  SprintSpeed  Agility  Reactions  \
# 0         77.0         84.0          72.0         68.0     76.0       92.0
# 1         93.0         92.0          77.0         76.0     78.0       91.0
# 2         87.0         88.0          78.0         76.0     79.0       86.0
# 3         82.0         89.0          80.0         79.0     91.0       92.0
# 4         78.0         87.0          77.0         75.0     82.0       83.0
#
#    Balance  ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 0     78.0       89.0     69.0     78.0      85.0       88.0        87.0
# 1     76.0       91.0     63.0     89.0      74.0       91.0        76.0
# 2     79.0       89.0     72.0     94.0      67.0       89.0        70.0
# 3     83.0       81.0     90.0     86.0      63.0       82.0        73.0
# 4     90.0       82.0     63.0     90.0      80.0       81.0        84.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0           41.0         91.0    84.0       83.0       85.0      NaN
# 1           66.0         88.0    94.0       84.0       91.0      NaN
# 2           74.0         83.0    90.0       91.0       86.0      NaN
# 3           49.0         89.0    85.0       86.0       89.0      NaN
# 4           78.0         81.0    82.0       76.0       87.0      NaN
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0            45.0           38.0      27.0        25.0       31.0
# 1            65.0           53.0      15.0        13.0        5.0
# 2            67.0           55.0      12.0        14.0       15.0
# 3            54.0           49.0      14.0         8.0       14.0
# 4            82.0           79.0       8.0        14.0       13.0
#
#    GKPositioning  GKReflexes Best+Position  Best+Overall+Rating  \
# 0           33.0        37.0         b'ST'                 87.0
# 1           10.0        13.0        b'CAM'                 91.0
# 2            8.0        14.0        b'CAM'                 88.0
# 3           13.0        14.0         b'ST'                 87.0
# 4           13.0        14.0         b'LB'                 83.0
#
#           Release+Clause  DefensiveAwareness
# 0   b'\xe2\x82\xac64.6M'                57.0
# 1    b'\xe2\x82\xac161M'                68.0
# 2  b'\xe2\x82\xac124.4M'                72.0
# 3  b'\xe2\x82\xac103.5M'                59.0
# 4   b'\xe2\x82\xac46.2M'                79.0

# %%
for col in fifa_df.columns:
    if fifa_df[col].dtype == object:
        fifa_df[col] = fifa_df[col].apply(lambda x: x.decode('utf-8') if isinstance(x, bytes) else x)

# %%
pd.set_option('display.max_columns', None)
fifa_df.head()
val_column = ['Value', 'Wage']
fifa21 = fifa_df[['Name', 'Age', 'Overall', 'Value', 'Wage']]
for col in val_column:
    fifa21[col] = fifa21[col].replace({'€': '', 'K': 'e3', 'M': 'e6'}, regex=True).astype(float)

fifa21.head()
# Out:
# /var/folders/h1/_hbxjbsn19g225k2l_p3t3cw0000gn/T/ipykernel_35483/3027459177.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fifa21[col] = fifa21[col].replace({'€': '', 'K': 'e3', 'M': 'e6'}, regex=True).astype(float)
# /var/folders/h1/_hbxjbsn19g225k2l_p3t3cw0000gn/T/ipykernel_35483/3027459177.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fifa21[col] = fifa21[col].replace({'€': '', 'K': 'e3', 'M': 'e6'}, regex=True).astype(float)
#                Name  Age  Overall       Value      Wage
# 0         L. Suárez   33       87  31500000.0  115000.0
# 1      K. De Bruyne   29       91  87000000.0  370000.0
# 2   Bruno Fernandes   25       87  63000000.0  195000.0
# 3      A. Griezmann   29       87  50500000.0  290000.0
# 4          M. Acuña   28       83  22000000.0   41000.0

# %%
X = fifa21[['Age', 'Overall', 'Value', 'Wage']]
X.shape
# Out:
# (17108, 4)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans
inertia = []
K = range(2, 11)
for k in K:
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(X_scaled)
    inertia.append(km.inertia_)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
plt.plot(K, inertia, marker='o')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("inertia")
plt.title("elbow Method for Optimal K")
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import silhouette_score
silhouette_scores = []
K = range(2, 11)
for k in K:
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(X_scaled)
    score = silhouette_score(X_scaled, km.labels_)
    silhouette_scores.append(score)

# %%
plt.figure(figsize=(8, 5))
plt.plot(K, silhouette_scores, marker='o')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Method for Optimal K")
plt.grid(True)
plt.show()

# %%
k_chosen = 4
kmeans = KMeans(n_clusters = k_chosen, random_state=42)
kmeans.fit(X_scaled)
Labels = kmeans.labels_

# %%
fifa21['Cluster'] = Labels

cluster_summary = fifa21.groupby('Cluster').mean(numeric_only=True)
cluster_summary
# Out:
# /var/folders/h1/_hbxjbsn19g225k2l_p3t3cw0000gn/T/ipykernel_35483/3757020747.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fifa21['Cluster'] = Labels
#                Age    Overall         Value           Wage
# Cluster
# 0        21.035591  61.492155  6.415876e+05    2601.613726
# 1        29.034548  69.192541  1.630196e+06    7540.835502
# 2        27.197531  85.290123  4.049691e+07  152339.506173
# 3        26.703518  76.723161  9.608931e+06   37318.181818

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(
    X_scaled[:, 0], X_scaled[:, 1], X_scaled[:, 2],
    c=Labels, cmap='viridis', s=50
)
ax.set_xlabel('Age (scaled)')
ax.set_ylabel('Overall (scaled)')
ax.set_zlabel('Value (scaled)')
ax.set_title('3D Scatter Plot of FIFA 18 Player Clusters')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(
    fifa21['Overall'], 
    fifa21['Value'], 
    fifa21['Age'],
    c=fifa21['Cluster'],
    cmap='viridis',
    s=40
)

ax.set_xlabel('Overall Rating')
ax.set_ylabel('Market Value (EUR)')
ax.set_zlabel('Age')
ax.set_title('3D Cluster Visualization (Overall, Value, Age)')
legend = ax.legend(*scatter.legend_elements(), title="Cluster")
ax.add_artist(legend)

plt.show()
